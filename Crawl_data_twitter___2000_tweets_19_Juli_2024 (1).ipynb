# %% [markdown]
# # Crawl Data Twitter > 2000 Tweets
# The crawling process was done using Tweet-Harvest. Written by Helmi Satria on  March 30th 2024.

# %%
#@title Twitter Auth Token

twitter_auth_token = '2dbeb01e27a07808b88b4f220dd759634092f80c' # change this auth token

# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %% [markdown]
# filename = 'vaksinasi_covid_surabaya.csv'
# Nama file yang diubah untuk
# mencerminkan data yang diambil
# search_keyword = 'vaksin OR Vaksin OR vaksinasi OR Vaksinasi AND covid OR Covid OR COVID OR Covid-19 OR COVID-19 OR covid-19 OR covid19 OR Covid19 OR COVID19 AND surabaya OR Surabaya lang:id'
# limit = 1500
# Batas jumlah tweet yang diambil

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,966 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# ...

# %% [markdown]
# # crawl pertama

# %%
# Crawl Data

filename = 'program_mbg.csv'
search_keyword = 'Program Makan Bergizi Gratis since:2025-04-01 until:2025-05-17 lang:id'
#since:2024-10-01 until:2025-05-10
limit = 1500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/program_mbg.csv, renaming to ./tweets-data/program_mbg.old.csv
#
# -- Scrolling... (1)
# Filling in keywords: Program Makan Bergizi Gratis since:2025-04-01 until:2025-05-17 lang:id
#
#  (2) (3)
#
# Your tweets saved to: /content/tweets-data/program_mbg.csv
# Total tweets saved: 16
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/program_mbg.csv
# Total tweets saved: 26
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/program_mbg.csv
# Total tweets saved: 31
#
#
# ...

# %% [markdown]
# # Crawl kedua

# %%
# Crawl Data

filename = 'program_mbg.csv'
search_keyword = 'Program MBG since:2025-01-06 until:2025-05-01 lang:id'
#since:2024-10-01 until:2025-05-10
limit = 1500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/program_mbg.csv, renaming to ./tweets-data/program_mbg.old.csv
#
# -- Scrolling... (1) (2)
# Filling in keywords: Program MBG since:2025-01-06 until:2025-05-01 lang:id
#
#  (3) (4) (5) (6) (7) (8)
#
# Your tweets saved to: /content/tweets-data/program_mbg.csv
# Total tweets saved: 18
#
# -- Scrolling... (1) (2) (3) (4) (5) (6) (7)
#
# Your tweets saved to: /content/tweets-data/program_mbg.csv
# Total tweets saved: 35
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/program_mbg.csv
# Total tweets saved: 48
#
#
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 1515.

# %%
from google.colab import files
files.download("tweets-data/program_mbg.csv") # Specify the correct path to the file
